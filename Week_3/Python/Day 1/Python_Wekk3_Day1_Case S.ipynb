# %%
import pandas as pd
import numpy as np

# %%
tr_df = pd.read_csv('train.csv')
tr_df
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# ...

# %% [markdown]
# # 1. Show first 7 observations in dataset

# %%
tr_df.head(7)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621  3.5609  4.5322
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355 -8.0198  6.1961
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# ...

# %% [markdown]
# # 2. Check if there are any missing values.

# %%
tr_df.isnull().any().any()
# Out:
# False

# %%
tr_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # 3. Find mean of each variable according to target.

# %%
tr_df.groupby('target').mean()
# Out:
#             var_0     var_1      var_2     var_3      var_4     var_5  \
# target
# 0       10.626681 -1.695770  10.665876  6.788979  11.072412 -5.146736
# 1       11.156418 -1.017613  11.156633  6.864113  11.131337 -4.336522
#
#            var_6      var_7     var_8     var_9  ...   var_190  var_191  \
# target                                           ...
# 0       5.389620  16.549306  0.262347  7.584907  ...  3.149130  7.39080
# 1       5.581966  16.514917  0.479432  7.409064  ...  3.998064  7.86456
#
#          var_192   var_193    var_194   var_195   var_196   var_197  \
# target
# 0       1.949017  3.355403  18.017716 -0.155601  2.260297  8.919032
# 1       1.738266  3.120260  17.779568 -0.021130  2.688583  8.810815
#
#           var_198   var_199
# target
# 0       15.924058 -3.415273
# 1       15.393283 -2.532243
#
# [2 rows x 200 columns]

# %% [markdown]
# # 4. Count number of values for each target.

# %%
tr_df[['target']].value_counts()
# Out:
# target
# 0         179902
# 1          20098
# dtype: int64

# %% [markdown]
# # 5. Remove ID_code column.

# %%
tr_df = df.drop('ID_code',axis=1)
tr_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
# ----> 1 tr_df = df.drop('ID_code',axis=1)
#       2 tr_df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %% [markdown]
# # 6. Get statistical summary for each variable.
# a. Give interpretation for std, min, max, mean.
# b. Show mean of var_0 by using indexing.

# %%
tr_df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
tr_df.var_0.describe().T[['mean','std','min','max']].T
# Out:
# mean    10.679914
# std      3.040051
# min      0.408400
# max     20.315000
# Name: var_0, dtype: float64

# %% [markdown]
# # 7. Filter var_0 variable from minimum to mean.

# %%
tr_df[tr_df['var_0'] < tr_df.var_0.describe() [1]] ['var_0']
# Out:
# 0         8.9255
# 2         8.6093
# 4         9.8369
# 10        5.0702
# 12        8.7671
#            ...
# 199985    9.0249
# 199987    8.0438
# 199991    9.9909
# 199996    4.9149
# 199998    9.7148
# Name: var_0, Length: 103673, dtype: float64

# %%
 tr_df[tr_df['var_0'] < tr_df.var_0.describe() [1]]['var_0'].sort_values()
# Out:
# 165885     0.4084
# 131672     0.4528
# 10693      0.5979
# 61234      0.8935
# 64498      0.9302
#            ...
# 37979     10.6798
# 179832    10.6799
# 35948     10.6799
# 40929     10.6799
# 160423    10.6799
# Name: var_0, Length: 103673, dtype: float64

# %% [markdown]
# # 8. Filter var_6 greater than 5 and var_196 less than 2.

# %%
tr_df[(tr_df['var_6']>5) & (tr_df['var_196']<2)] [['var_6','var_196']]
# Out:
#          var_6  var_196
# 2       6.9427  -6.5213
# 3       5.8428  -2.9275
# 11      5.6464  -1.7183
# 14      5.7327  -3.5323
# 16      5.2757  -3.4975
# ...        ...      ...
# 199990  5.3217  -4.0032
# 199991  6.0864  -5.3444
# 199994  7.0503  -3.9299
# 199996  5.8802  -2.1651
# 199999  5.2839  -2.2342
#
# [62455 rows x 2 columns]

# %% [markdown]
# # 9. Show observations between 20000 and 30000 for 11th column.

# %%
tr_df[['var_10']][20000:30001]
# Out:
#         var_10
# 20000   4.8219
# 20001   4.1234
# 20002   1.5339
# 20003   5.2597
# 20004  10.2969
# ...        ...
# 29996   8.3554
# 29997  -1.3356
# 29998  -0.0461
# 29999  -1.9111
# 30000  -6.9853
#
# [10001 rows x 1 columns]

# %% [markdown]
# # 10. Create features list including variables from var_0 to var_9.
# a. Find correlations in features.
# b. Sort most correlated variables in features.
# c. Show top 10 most correlated variables in features.

# %%
features = ('var_0 var_1  var_2  var_3  var_4 var_5').split()
features
tr_df[features].corr()
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5
# var_0  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046
# var_1 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569
# var_3  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253
# var_4  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368
# var_5  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000

# %%
tr_df[features].corr().abs()
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5
# var_0  1.000000  0.000544  0.006573  0.003801  0.001326  0.003046
# var_1  0.000544  1.000000  0.003980  0.000010  0.000303  0.000902
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569
# var_3  0.003801  0.000010  0.001001  1.000000  0.000322  0.003253
# var_4  0.001326  0.000303  0.000723  0.000322  1.000000  0.001368
# var_5  0.003046  0.000902  0.001569  0.003253  0.001368  1.000000

# %%
tr_df[features].corr().abs().unstack()
# Out:
# var_0  var_0    1.000000
#        var_1    0.000544
#        var_2    0.006573
#        var_3    0.003801
#        var_4    0.001326
#        var_5    0.003046
# var_1  var_0    0.000544
#        var_1    1.000000
#        var_2    0.003980
#        var_3    0.000010
#        var_4    0.000303
#        var_5    0.000902
# var_2  var_0    0.006573
#        var_1    0.003980
#        var_2    1.000000
#        var_3    0.001001
#        var_4    0.000723
#        var_5    0.001569
# var_3  var_0    0.003801
#        var_1    0.000010
#        var_2    0.001001
#        var_3    1.000000
#        var_4    0.000322
#        var_5    0.003253
# var_4  var_0    0.001326
#        var_1    0.000303
#        var_2    0.000723
#        var_3    0.000322
#        var_4    1.000000
#        var_5    0.001368
# var_5  var_0    0.003046
#        var_1    0.000902
#        var_2    0.001569
#        var_3    0.003253
#        var_4    0.001368
#        var_5    1.000000
# dtype: float64

# %%
tr_df[features].corr().abs().unstack().sort_values()
# Out:
# var_1  var_3    0.000010
# var_3  var_1    0.000010
# var_4  var_1    0.000303
# var_1  var_4    0.000303
# var_3  var_4    0.000322
# var_4  var_3    0.000322
# var_0  var_1    0.000544
# var_1  var_0    0.000544
# var_4  var_2    0.000723
# var_2  var_4    0.000723
# var_1  var_5    0.000902
# var_5  var_1    0.000902
# var_3  var_2    0.001001
# var_2  var_3    0.001001
# var_0  var_4    0.001326
# var_4  var_0    0.001326
#        var_5    0.001368
# var_5  var_4    0.001368
# var_2  var_5    0.001569
# var_5  var_2    0.001569
#        var_0    0.003046
# var_0  var_5    0.003046
# var_3  var_5    0.003253
# var_5  var_3    0.003253
# var_0  var_3    0.003801
# var_3  var_0    0.003801
# var_2  var_1    0.003980
# var_1  var_2    0.003980
# var_2  var_0    0.006573
# var_0  var_2    0.006573
#        var_0    1.000000
# var_3  var_3    1.000000
# var_2  var_2    1.000000
# var_1  var_1    1.000000
# var_4  var_4    1.000000
# var_5  var_5    1.000000
# dtype: float64

# %%
tr_df[features].corr().abs().unstack().sort_values().reset_index()
# Out:
#    level_0 level_1         0
# 0    var_1   var_3  0.000010
# 1    var_3   var_1  0.000010
# 2    var_4   var_1  0.000303
# 3    var_1   var_4  0.000303
# 4    var_3   var_4  0.000322
# 5    var_4   var_3  0.000322
# 6    var_0   var_1  0.000544
# 7    var_1   var_0  0.000544
# 8    var_4   var_2  0.000723
# 9    var_2   var_4  0.000723
# 10   var_1   var_5  0.000902
# 11   var_5   var_1  0.000902
# 12   var_3   var_2  0.001001
# 13   var_2   var_3  0.001001
# 14   var_0   var_4  0.001326
# 15   var_4   var_0  0.001326
# 16   var_4   var_5  0.001368
# 17   var_5   var_4  0.001368
# 18   var_2   var_5  0.001569
# 19   var_5   var_2  0.001569
# 20   var_5   var_0  0.003046
# 21   var_0   var_5  0.003046
# 22   var_3   var_5  0.003253
# 23   var_5   var_3  0.003253
# 24   var_0   var_3  0.003801
# 25   var_3   var_0  0.003801
# 26   var_2   var_1  0.003980
# 27   var_1   var_2  0.003980
# 28   var_2   var_0  0.006573
# 29   var_0   var_2  0.006573
# 30   var_0   var_0  1.000000
# ...

# %%
corr=tr_df[features].corr().abs().unstack().sort_values(ascending=False).reset_index()
corr=corr[corr['level_0'] !=corr['level_1']]
corr
# Out:
#    level_0 level_1         0
# 6    var_2   var_0  0.006573
# 7    var_0   var_2  0.006573
# 8    var_1   var_2  0.003980
# 9    var_2   var_1  0.003980
# 10   var_0   var_3  0.003801
# 11   var_3   var_0  0.003801
# 12   var_5   var_3  0.003253
# 13   var_3   var_5  0.003253
# 14   var_0   var_5  0.003046
# 15   var_5   var_0  0.003046
# 16   var_2   var_5  0.001569
# 17   var_5   var_2  0.001569
# 18   var_4   var_5  0.001368
# 19   var_5   var_4  0.001368
# 20   var_4   var_0  0.001326
# 21   var_0   var_4  0.001326
# 22   var_2   var_3  0.001001
# 23   var_3   var_2  0.001001
# 24   var_5   var_1  0.000902
# 25   var_1   var_5  0.000902
# 26   var_4   var_2  0.000723
# 27   var_2   var_4  0.000723
# 28   var_0   var_1  0.000544
# 29   var_1   var_0  0.000544
# 30   var_4   var_3  0.000322
# 31   var_3   var_4  0.000322
# 32   var_4   var_1  0.000303
# 33   var_1   var_4  0.000303
# 34   var_1   var_3  0.000010
# 35   var_3   var_1  0.000010

# %%
corr.head()
# Out:
#    level_0 level_1         0
# 6    var_2   var_0  0.006573
# 7    var_0   var_2  0.006573
# 8    var_1   var_2  0.003980
# 9    var_2   var_1  0.003980
# 10   var_0   var_3  0.003801

# %%
corr.head(20)[0::2]
# Out:
#    level_0 level_1         0
# 6    var_2   var_0  0.006573
# 8    var_1   var_2  0.003980
# 10   var_0   var_3  0.003801
# 12   var_5   var_3  0.003253
# 14   var_0   var_5  0.003046
# 16   var_2   var_5  0.001569
# 18   var_4   var_5  0.001368
# 20   var_4   var_0  0.001326
# 22   var_2   var_3  0.001001
# 24   var_5   var_1  0.000902
